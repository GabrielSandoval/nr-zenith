# %%
import os
import pandas as pd
from PIL import Image
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

def process_directory(directory, label):
    features = []
    for filename in os.listdir(directory):
        if filename.endswith(".png"): 
            filepath = os.path.join(directory, filename)
#             print(filepath)
            features.append(preprocess(filepath))
    return features

def preprocess(filepath):
    image = Image.open(filepath).convert('L')
    image_array = np.array(image)
    height, width = image_array.shape
    return list(image_array.reshape(height*width,))

# %%
def train_wave():
    negative_samples = process_directory("negative-wave", 0)
    negative_samples = pd.DataFrame(np.array(negative_samples, dtype=np.float32)/255)
    negative_samples["label"] = 0

    positive_samples = process_directory("positive-wave", 1)
    positive_samples = pd.DataFrame(np.array(positive_samples, dtype=np.float32)/255)
    positive_samples["label"] = 1

    dataset = pd.concat([negative_samples, positive_samples])

    X = dataset.drop('label', axis=1)
    Y = dataset["label"]
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    model = MLPClassifier(hidden_layer_sizes=(16, 16), max_iter=500, alpha=1e-4, solver='adam', verbose=0)
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)

    f1score = f1_score(y_test, predictions).round(4)
    accuracy = accuracy_score(y_test, predictions).round(4)
    cm = confusion_matrix(y_test,predictions)

    print("F1Score: {}".format(f1score))
    print("Accuracy: {}".format(accuracy))
    print("Confusion Matrix:\n{}".format(cm))
    
    return model
wave_model = train_wave()
# Out:
# F1Score: 0.8571
# Accuracy: 0.8919
# Confusion Matrix:
# [[21  2]
#  [ 2 12]]

# %%
def train_drop():
    negative_samples = process_directory("negative-drop", 0)
    negative_samples = pd.DataFrame(np.array(negative_samples, dtype=np.float32)/255)
    negative_samples["label"] = 0

    positive_samples = process_directory("positive-drop", 1)
    positive_samples = pd.DataFrame(np.array(positive_samples, dtype=np.float32)/255)
    positive_samples["label"] = 1

    dataset = pd.concat([negative_samples, positive_samples])

    X = dataset.drop('label', axis=1)
    Y = dataset["label"]
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)
    
    model = MLPClassifier(hidden_layer_sizes=(16, 16), max_iter=1000, alpha=1e-4, solver='adam', verbose=0)
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)

    f1score = f1_score(y_test, predictions).round(4)
    accuracy = accuracy_score(y_test, predictions).round(4)
    cm = confusion_matrix(y_test,predictions)

    print("F1Score: {}".format(f1score))
    print("Accuracy: {}".format(accuracy))
    print("Confusion Matrix:\n{}".format(cm))
    
    return model
drop_model = train_drop()
# Out:
# F1Score: 1.0
# Accuracy: 1.0
# Confusion Matrix:
# [[6 0]
#  [0 5]]

# %%
import cv2
from mss import mss
import time
import pyautogui

import ctypes
user32 = ctypes.windll.user32
screensize = user32.GetSystemMetrics(0), user32.GetSystemMetrics(1)
screensize
# Out:
# (3440, 1440)

# %%
def grab_drops(sct):
#     monitor = {'top': 200, 'left': 2400, 'width': 300, 'height': 150}
    monitor = {'top': 200, 'left': 2700, 'width': 300, 'height': 150}
    
    # Get raw pixels from the screen, save it to a Numpy array
    img = np.array(sct.grab(monitor))
    
    # Display the picture
    # cv2.imshow("OpenCV/Numpy normal", img)

    #Display the picture in grayscale
    
    winname = "Drops"
    cv2.namedWindow(winname) 
    cv2.moveWindow(winname, 450, 10) 
    cv2.imshow(winname, cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY))
    return img
    
def grab_wave(sct):
    wave = {'top': 100, 'left': 3200, 'width': 200, 'height': 100}
    img = np.array(sct.grab(wave))
    
    
    winname = "Wave"
    cv2.namedWindow(winname) 
    cv2.moveWindow(winname, 10, 10) 
    cv2.imshow(winname, cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY))
    return img

# %%
WAVE_LIMIT = 100
DROP_LIMIT = 50
state = "battle"

with mss() as sct:
    # Part of the screen to capture

    wave_counter = 0
    drop_counter = 0
    no_drop_counter = 0
    
    while "Screen capturing":
        last_time = time.time()
        
        wave = grab_wave(sct)
        wave = cv2.cvtColor(wave, cv2.COLOR_BGRA2GRAY)/255
        height, width = wave.shape
        wave_prediction = wave_model.predict([wave.reshape(height*width,)])[0]

        if state == "battle" and wave_prediction == 1:
            print("[{}][{}/{}] WAVE 3 Detected".format(state, wave_counter, WAVE_LIMIT))
            wave_counter += 1

            if wave_counter > WAVE_LIMIT:
                print("[{}][{}/{}] WAVE 3 Detected > {} times. Pressing 'ESC' now.".format(state, wave_counter, WAVE_LIMIT, WAVE_LIMIT))
                pyautogui.press('escape')
                state = "menu"
                wave_counter = 0
        
        drop = grab_drops(sct)
        drop = cv2.cvtColor(drop, cv2.COLOR_BGRA2GRAY)/255
        height, width = drop.shape

        drop_prediction = drop_model.predict([drop.reshape(height*width,)])[0]

        if state == "menu":
            if drop_prediction == 1:
                print("[{}][{}/{}] PURPLE DROP Detected.".format(state, drop_counter, DROP_LIMIT))
                drop_counter += 1

                if drop_counter > DROP_LIMIT:
                    print("[{}][{}/{}] PURPLE DROP Detected > {} times.".format(state, drop_counter, DROP_LIMIT, DROP_LIMIT))
                    pyautogui.click(x=2500, y=875)
                    state == "battle"
                    drop_counter = 0

            if drop_prediction == 0:
                print("[{}][{}/{}] NO PURPLE DROP".format(state, no_drop_counter, DROP_LIMIT))
                no_drop_counter += 1

                if no_drop_counter > DROP_LIMIT:
                    print("[{}][{}/{}] NO PURPLE DROP. Quitting battle.".format(state, no_drop_counter, DROP_LIMIT))
                    pyautogui.click(x=2650, y=775, interval=2.5)
                    pyautogui.click(x=2665, y=775, interval=0.25)
                    state = "battle"
                    no_drop_counter = 0

#         print("fps: {}".format(1 / (time.time() - last_time)))

        # Press "q" to quit
        if cv2.waitKey(25) & 0xFF == ord("q"):
            cv2.destroyAllWindows()
            break
# Out:
# [battle][0/100] WAVE 3 Detected
# [battle][1/100] WAVE 3 Detected
# [battle][2/100] WAVE 3 Detected
# [battle][3/100] WAVE 3 Detected
# [battle][4/100] WAVE 3 Detected
# [battle][5/100] WAVE 3 Detected
# [battle][6/100] WAVE 3 Detected
# [battle][7/100] WAVE 3 Detected
# [battle][8/100] WAVE 3 Detected
# [battle][9/100] WAVE 3 Detected
# [battle][10/100] WAVE 3 Detected
# [battle][11/100] WAVE 3 Detected
# [battle][12/100] WAVE 3 Detected
# [battle][13/100] WAVE 3 Detected
# [battle][14/100] WAVE 3 Detected
# [battle][15/100] WAVE 3 Detected
# [battle][16/100] WAVE 3 Detected
# [battle][17/100] WAVE 3 Detected
# [battle][18/100] WAVE 3 Detected
# [battle][19/100] WAVE 3 Detected
# [battle][20/100] WAVE 3 Detected
# [battle][21/100] WAVE 3 Detected
# [battle][22/100] WAVE 3 Detected
# [battle][23/100] WAVE 3 Detected
# [battle][24/100] WAVE 3 Detected
# [battle][25/100] WAVE 3 Detected
# [battle][26/100] WAVE 3 Detected
# [battle][27/100] WAVE 3 Detected
# [battle][28/100] WAVE 3 Detected
# [battle][29/100] WAVE 3 Detected
# [battle][30/100] WAVE 3 Detected
# [battle][31/100] WAVE 3 Detected
# [battle][32/100] WAVE 3 Detected
# [battle][33/100] WAVE 3 Detected
# [battle][34/100] WAVE 3 Detected
# [battle][35/100] WAVE 3 Detected
# [battle][36/100] WAVE 3 Detected
# [battle][37/100] WAVE 3 Detected
# [battle][38/100] WAVE 3 Detected
# [battle][39/100] WAVE 3 Detected
# [battle][40/100] WAVE 3 Detected
# [battle][41/100] WAVE 3 Detected
# [battle][42/100] WAVE 3 Detected
# [battle][43/100] WAVE 3 Detected
# [battle][44/100] WAVE 3 Detected
# [battle][45/100] WAVE 3 Detected
# [battle][46/100] WAVE 3 Detected
# [battle][47/100] WAVE 3 Detected
# [battle][48/100] WAVE 3 Detected
# [battle][49/100] WAVE 3 Detected
# [battle][50/100] WAVE 3 Detected
# [battle][51/100] WAVE 3 Detected
# [battle][52/100] WAVE 3 Detected
# [battle][53/100] WAVE 3 Detected
# [battle][54/100] WAVE 3 Detected
# [battle][55/100] WAVE 3 Detected
# [battle][56/100] WAVE 3 Detected
# [battle][57/100] WAVE 3 Detected
# [battle][58/100] WAVE 3 Detected
# [battle][59/100] WAVE 3 Detected
# [battle][60/100] WAVE 3 Detected
# [battle][61/100] WAVE 3 Detected
# [battle][62/100] WAVE 3 Detected
# [battle][63/100] WAVE 3 Detected
# [battle][64/100] WAVE 3 Detected
# [battle][65/100] WAVE 3 Detected
# [battle][66/100] WAVE 3 Detected
# [battle][67/100] WAVE 3 Detected
# [battle][68/100] WAVE 3 Detected
# [battle][69/100] WAVE 3 Detected
# [battle][70/100] WAVE 3 Detected
# [battle][71/100] WAVE 3 Detected
# [battle][72/100] WAVE 3 Detected
# [battle][73/100] WAVE 3 Detected
# [battle][74/100] WAVE 3 Detected
# [battle][75/100] WAVE 3 Detected
# [battle][76/100] WAVE 3 Detected
# [battle][77/100] WAVE 3 Detected
# [battle][78/100] WAVE 3 Detected
# [battle][79/100] WAVE 3 Detected
# [battle][80/100] WAVE 3 Detected
# [battle][81/100] WAVE 3 Detected
# [battle][82/100] WAVE 3 Detected
# [battle][83/100] WAVE 3 Detected
# [battle][84/100] WAVE 3 Detected
# [battle][85/100] WAVE 3 Detected
# [battle][86/100] WAVE 3 Detected
# [battle][87/100] WAVE 3 Detected
# [battle][88/100] WAVE 3 Detected
# [battle][89/100] WAVE 3 Detected
# [battle][90/100] WAVE 3 Detected
# [battle][91/100] WAVE 3 Detected
# [battle][92/100] WAVE 3 Detected
# [battle][93/100] WAVE 3 Detected
# [battle][94/100] WAVE 3 Detected
# [battle][95/100] WAVE 3 Detected
# [battle][96/100] WAVE 3 Detected
# [battle][97/100] WAVE 3 Detected
# [battle][98/100] WAVE 3 Detected
# [battle][99/100] WAVE 3 Detected
# [battle][100/100] WAVE 3 Detected
# [battle][101/100] WAVE 3 Detected > 100 times. Pressing 'ESC' now.
# [menu][0/50] NO PURPLE DROP
# [menu][1/50] NO PURPLE DROP
# [menu][2/50] NO PURPLE DROP
# [menu][3/50] NO PURPLE DROP
# [menu][4/50] NO PURPLE DROP
# [menu][5/50] NO PURPLE DROP
# [menu][6/50] NO PURPLE DROP
# [menu][0/50] PURPLE DROP Detected.
# [menu][1/50] PURPLE DROP Detected.
# [menu][2/50] PURPLE DROP Detected.
# [menu][3/50] PURPLE DROP Detected.
# [menu][4/50] PURPLE DROP Detected.
# [menu][5/50] PURPLE DROP Detected.
# [menu][6/50] PURPLE DROP Detected.
# [menu][7/50] PURPLE DROP Detected.
# [menu][8/50] PURPLE DROP Detected.
# [menu][9/50] PURPLE DROP Detected.
# [menu][10/50] PURPLE DROP Detected.
# [menu][11/50] PURPLE DROP Detected.
# [menu][12/50] PURPLE DROP Detected.
# [menu][13/50] PURPLE DROP Detected.
# [menu][14/50] PURPLE DROP Detected.
# [menu][15/50] PURPLE DROP Detected.
# [menu][16/50] PURPLE DROP Detected.
# [menu][17/50] PURPLE DROP Detected.
# [menu][18/50] PURPLE DROP Detected.
# [menu][19/50] PURPLE DROP Detected.
# [menu][20/50] PURPLE DROP Detected.
# [menu][21/50] PURPLE DROP Detected.
# [menu][22/50] PURPLE DROP Detected.
# [menu][23/50] PURPLE DROP Detected.
# [menu][24/50] PURPLE DROP Detected.
# [menu][25/50] PURPLE DROP Detected.
# [menu][26/50] PURPLE DROP Detected.
# [menu][27/50] PURPLE DROP Detected.
# [menu][28/50] PURPLE DROP Detected.
# [menu][29/50] PURPLE DROP Detected.
# [menu][30/50] PURPLE DROP Detected.
# [menu][31/50] PURPLE DROP Detected.
# [menu][32/50] PURPLE DROP Detected.
# [menu][33/50] PURPLE DROP Detected.
# [menu][34/50] PURPLE DROP Detected.
# [menu][35/50] PURPLE DROP Detected.
# [menu][36/50] PURPLE DROP Detected.
# [menu][37/50] PURPLE DROP Detected.
# [menu][38/50] PURPLE DROP Detected.
# [menu][39/50] PURPLE DROP Detected.
# [menu][40/50] PURPLE DROP Detected.
# [menu][41/50] PURPLE DROP Detected.
# [menu][42/50] PURPLE DROP Detected.
# [menu][43/50] PURPLE DROP Detected.
# [menu][44/50] PURPLE DROP Detected.
# [menu][45/50] PURPLE DROP Detected.
# [menu][46/50] PURPLE DROP Detected.
# [menu][47/50] PURPLE DROP Detected.
# [menu][48/50] PURPLE DROP Detected.
# [menu][49/50] PURPLE DROP Detected.
# [menu][50/50] PURPLE DROP Detected.
# [menu][51/50] PURPLE DROP Detected > 50 times.
# [menu][0/50] PURPLE DROP Detected.
# [menu][1/50] PURPLE DROP Detected.
# [menu][2/50] PURPLE DROP Detected.
# [menu][7/50] NO PURPLE DROP
# [menu][8/50] NO PURPLE DROP
# [menu][9/50] NO PURPLE DROP
# [menu][10/50] NO PURPLE DROP
# [menu][11/50] NO PURPLE DROP
# [menu][12/50] NO PURPLE DROP
# [menu][13/50] NO PURPLE DROP
# [menu][14/50] NO PURPLE DROP
# [menu][15/50] NO PURPLE DROP
# [menu][16/50] NO PURPLE DROP
# [menu][17/50] NO PURPLE DROP
# [menu][18/50] NO PURPLE DROP
# [menu][19/50] NO PURPLE DROP
# [menu][20/50] NO PURPLE DROP
# [menu][21/50] NO PURPLE DROP
# [menu][22/50] NO PURPLE DROP
# [menu][23/50] NO PURPLE DROP
# [menu][24/50] NO PURPLE DROP
# [menu][25/50] NO PURPLE DROP
# [menu][26/50] NO PURPLE DROP
# [menu][27/50] NO PURPLE DROP
# [menu][28/50] NO PURPLE DROP
# [menu][29/50] NO PURPLE DROP
# [menu][30/50] NO PURPLE DROP
# [menu][31/50] NO PURPLE DROP
# [menu][32/50] NO PURPLE DROP
# [menu][33/50] NO PURPLE DROP
# [menu][34/50] NO PURPLE DROP
# [menu][35/50] NO PURPLE DROP
# [menu][36/50] NO PURPLE DROP
# [menu][37/50] NO PURPLE DROP
# [menu][38/50] NO PURPLE DROP
# [menu][39/50] NO PURPLE DROP
# [menu][40/50] NO PURPLE DROP
# [menu][41/50] NO PURPLE DROP
# [menu][42/50] NO PURPLE DROP
# [menu][43/50] NO PURPLE DROP
# [menu][44/50] NO PURPLE DROP
# [menu][45/50] NO PURPLE DROP
# [menu][46/50] NO PURPLE DROP
# [menu][47/50] NO PURPLE DROP
# [menu][48/50] NO PURPLE DROP
# [menu][49/50] NO PURPLE DROP
# [menu][50/50] NO PURPLE DROP
# [menu][51/50] NO PURPLE DROP. Quitting battle.
# [battle][0/100] WAVE 3 Detected
# [battle][1/100] WAVE 3 Detected
# [battle][2/100] WAVE 3 Detected
# [battle][3/100] WAVE 3 Detected
# [battle][4/100] WAVE 3 Detected
# [battle][5/100] WAVE 3 Detected
# [battle][6/100] WAVE 3 Detected
# [battle][7/100] WAVE 3 Detected
# [battle][8/100] WAVE 3 Detected
# [battle][9/100] WAVE 3 Detected
# [battle][10/100] WAVE 3 Detected
# [battle][11/100] WAVE 3 Detected
# [battle][12/100] WAVE 3 Detected
# [battle][13/100] WAVE 3 Detected
# [battle][14/100] WAVE 3 Detected
# [battle][15/100] WAVE 3 Detected
# [battle][16/100] WAVE 3 Detected
# [battle][17/100] WAVE 3 Detected
# [battle][18/100] WAVE 3 Detected
# [battle][19/100] WAVE 3 Detected
# [battle][20/100] WAVE 3 Detected
# [battle][21/100] WAVE 3 Detected
# [battle][22/100] WAVE 3 Detected
# [battle][23/100] WAVE 3 Detected
# [battle][24/100] WAVE 3 Detected
# [battle][25/100] WAVE 3 Detected
# [battle][26/100] WAVE 3 Detected
# [battle][27/100] WAVE 3 Detected
# [battle][28/100] WAVE 3 Detected
# [battle][29/100] WAVE 3 Detected
# [battle][30/100] WAVE 3 Detected
# [battle][31/100] WAVE 3 Detected
# [battle][32/100] WAVE 3 Detected
# [battle][33/100] WAVE 3 Detected
# [battle][34/100] WAVE 3 Detected
# [battle][35/100] WAVE 3 Detected
# [battle][36/100] WAVE 3 Detected
# [battle][37/100] WAVE 3 Detected
# [battle][38/100] WAVE 3 Detected
# [battle][39/100] WAVE 3 Detected
# [battle][40/100] WAVE 3 Detected
# [battle][41/100] WAVE 3 Detected
# [battle][42/100] WAVE 3 Detected
# [battle][43/100] WAVE 3 Detected
# [battle][44/100] WAVE 3 Detected
# [battle][45/100] WAVE 3 Detected
# [battle][46/100] WAVE 3 Detected
# [battle][47/100] WAVE 3 Detected
# [battle][48/100] WAVE 3 Detected
# [battle][49/100] WAVE 3 Detected
# [battle][50/100] WAVE 3 Detected
# [battle][51/100] WAVE 3 Detected
# [battle][52/100] WAVE 3 Detected
# [battle][53/100] WAVE 3 Detected
# [battle][54/100] WAVE 3 Detected
# [battle][55/100] WAVE 3 Detected
# [battle][56/100] WAVE 3 Detected
# [battle][57/100] WAVE 3 Detected
# [battle][58/100] WAVE 3 Detected
# [battle][59/100] WAVE 3 Detected
# [battle][60/100] WAVE 3 Detected
# [battle][61/100] WAVE 3 Detected
# [battle][62/100] WAVE 3 Detected
# [battle][63/100] WAVE 3 Detected
# [battle][64/100] WAVE 3 Detected
# [battle][65/100] WAVE 3 Detected
# [battle][66/100] WAVE 3 Detected
# [battle][67/100] WAVE 3 Detected
# [battle][68/100] WAVE 3 Detected
# [battle][69/100] WAVE 3 Detected
# [battle][70/100] WAVE 3 Detected
# [battle][71/100] WAVE 3 Detected
# [battle][72/100] WAVE 3 Detected
# [battle][73/100] WAVE 3 Detected
# [battle][74/100] WAVE 3 Detected
# [battle][75/100] WAVE 3 Detected
# [battle][76/100] WAVE 3 Detected
# [battle][77/100] WAVE 3 Detected
# [battle][78/100] WAVE 3 Detected
# [battle][79/100] WAVE 3 Detected
# [battle][80/100] WAVE 3 Detected
# [battle][81/100] WAVE 3 Detected
# [battle][82/100] WAVE 3 Detected
# [battle][83/100] WAVE 3 Detected
# [battle][84/100] WAVE 3 Detected
# [battle][85/100] WAVE 3 Detected
# [battle][86/100] WAVE 3 Detected
# [battle][87/100] WAVE 3 Detected
# [battle][88/100] WAVE 3 Detected
# [battle][89/100] WAVE 3 Detected
# [battle][90/100] WAVE 3 Detected
# [battle][91/100] WAVE 3 Detected
# [battle][92/100] WAVE 3 Detected
# [battle][93/100] WAVE 3 Detected
# [battle][94/100] WAVE 3 Detected
# [battle][95/100] WAVE 3 Detected
# [battle][96/100] WAVE 3 Detected
# [battle][97/100] WAVE 3 Detected
# [battle][98/100] WAVE 3 Detected
# [battle][99/100] WAVE 3 Detected
# [battle][100/100] WAVE 3 Detected
# [battle][101/100] WAVE 3 Detected > 100 times. Pressing 'ESC' now.
# [menu][0/50] NO PURPLE DROP
# [menu][1/50] NO PURPLE DROP
# [menu][2/50] NO PURPLE DROP
# [menu][3/50] NO PURPLE DROP
# [menu][4/50] NO PURPLE DROP
# [menu][5/50] NO PURPLE DROP
# [menu][6/50] NO PURPLE DROP
# [menu][7/50] NO PURPLE DROP
# [menu][8/50] NO PURPLE DROP
# [menu][9/50] NO PURPLE DROP
# [menu][10/50] NO PURPLE DROP
# [menu][11/50] NO PURPLE DROP
# [menu][12/50] NO PURPLE DROP
# [menu][13/50] NO PURPLE DROP
# [menu][14/50] NO PURPLE DROP
# [menu][15/50] NO PURPLE DROP
# [menu][16/50] NO PURPLE DROP
# [menu][17/50] NO PURPLE DROP
# [menu][18/50] NO PURPLE DROP
# [menu][19/50] NO PURPLE DROP
# [menu][20/50] NO PURPLE DROP
# [menu][21/50] NO PURPLE DROP
# [menu][22/50] NO PURPLE DROP
# [menu][23/50] NO PURPLE DROP
# [menu][24/50] NO PURPLE DROP
# [menu][25/50] NO PURPLE DROP
# [menu][26/50] NO PURPLE DROP
# [menu][27/50] NO PURPLE DROP
# [menu][28/50] NO PURPLE DROP
# [menu][29/50] NO PURPLE DROP
# [menu][30/50] NO PURPLE DROP
# [menu][31/50] NO PURPLE DROP
# [menu][32/50] NO PURPLE DROP
# [menu][33/50] NO PURPLE DROP
# [menu][34/50] NO PURPLE DROP
# [menu][35/50] NO PURPLE DROP
# [menu][36/50] NO PURPLE DROP
# [menu][37/50] NO PURPLE DROP
# [menu][38/50] NO PURPLE DROP
# [menu][39/50] NO PURPLE DROP
# [menu][40/50] NO PURPLE DROP
# [menu][41/50] NO PURPLE DROP
# [menu][42/50] NO PURPLE DROP
# [menu][43/50] NO PURPLE DROP
# [menu][44/50] NO PURPLE DROP
# [menu][45/50] NO PURPLE DROP
# [menu][46/50] NO PURPLE DROP
# [menu][47/50] NO PURPLE DROP
# [menu][48/50] NO PURPLE DROP
# [menu][49/50] NO PURPLE DROP
# [menu][50/50] NO PURPLE DROP
# [menu][51/50] NO PURPLE DROP. Quitting battle.
